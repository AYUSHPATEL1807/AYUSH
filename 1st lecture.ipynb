# %%
e = 45
print(e)
print(type(e))
print(id(e))
# Out:
# 45
# <class 'int'>
# 2229447192240

# %%
e = 56,65
print(e)
print(id(e))
# Out:
# (56, 65)
# 2229561768320

# %%
print(e)

# %%
'''
this is my 
first python 
program
'''
print('Good')

# %%
r = 56
print(type(r))
# Out:
# <class 'int'>

# %%
x = str(56)
print(x)
print(type(x))
# Out:
# 56
# <class 'str'>

# %%
u = int(x)
print(u)
print(type(u))
# Out:
# 56
# <class 'int'>

# %%
t = int("hello")
print(t)
print(type(t))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 t = int("hello")
#       2 print(t)
#       3 print(type(t))
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
e,y,i = "Red","Blue","Yellow"
print(e)
#print(y)
print(i)
# Out:
# Red
# Yellow

# %%
f = """welcome to 
the python
programming
course
"""
print(f)
# Out:
# welcome to
# the python
# programming
# course

# %%
g = '''
this is my 
first python 
program
'''
print(g)
print('Good')
# Out:
# this is my
# first python
# program
#
# Good

# %%
w = q = y = "Apple"
print(w)
print(q)
print(y)
# Out:
# Apple
# Apple
# Apple

# %%
w,q,y = "Apple","Orange","KIWI"
print(w)
print(q)
print(y)
# Out:
# Apple
# Orange
# KIWI
